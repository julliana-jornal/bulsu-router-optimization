# %%
edges = { 
    'R1': ['A', 'B', 'C', 'D', 'E', 'F'], 
    'R2': ['A', 'B', 'C', 'D', 'E', 'F'],
    'R3': ['A', 'B', 'C', 'D', 'E', 'F'], 
    'R4': ['A', 'B', 'C', 'D', 'E', 'F']
}

G = Graph(edges)

pos = {

    'R1': (4, 7),
    'R2': (7, 4),
    'R3': (7, 6),
    'R4': (10, 5),

    'A': (5, 3),
    'B': (8, 4),
    'C': (5, 4.5),
    'D': (3, 8),
    'E': (6, 8),
    'F': (9, 6),
}

G.set_pos(pos)

G.show(title="Router Coverage Ground Floor")
# Out:
# Graphics object consisting of 35 graphics primitives

# %%
edges = { 
    'R1': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'K', 'L', ], 
    'R2': ['A', 'B', 'C', 'D', 'E', 'F', 'G','I', 'K','L', ],
    'R3': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', ], 
    'R4': ['A', 'B', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'L' ],
    'R5': ['B','D', 'E', 'F', 'G', 'H', 'I', 'J', 'L' ]
}

G2 = Graph(edges)

pos = {
    'R1': (4, 3),
    'R2': (4, 5),
    'R3': (10, 6),
    'R4': (11, 4),
    'R5': (13, 6),

    'A' : (3,3),
    'B' : (5,3),
    'C': (2,5),
    'D': (5,5),
    'E': (9.5,5),
    'F' : (9,7),
    'G': (12,5),
    'H': (14,4),
    'I' : (12.5,7),
    'J' : (14,7),
    'K' : (2, 6), 
    'L' : (5, 6),
}

G2.set_pos(pos)

G2.show(title="Router Coverage 2nd Floor")
# Out:
# Graphics object consisting of 68 graphics primitives

# %%
edges = { 
    'R1': ['A', 'B', 'C', 'D', 'E', 'F', 'G' ], 
    'R2': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R3': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R4': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R5': ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R6': ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
}

G3 = Graph(edges)

pos = {
    'R1': (3, 4),
    'R2': (6, 4),
    'R3': (9, 2),
    'R4': (10, 4),
    'R5': (13, 3),
    'R6': (13, 6),

    'A' : (4,3),
    'B' : (2,5),
    'C': (5,5),
    'D': (8,1),
    'E': (8,2.5),
    'F' : (8,3.5),
    'G': (10,5),
    'H': (12,5),
    'I' : (14,4),
    'J' : (14,7),
}

G3.set_pos(pos)

G3.show(title="Router Coverage 3rd Floor")
# Out:
# Graphics object consisting of 70 graphics primitives

# %%
edges = { 
    'R1': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'J' ], 
    'R2': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'J' ], 
    'R3': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R4': ['D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R5': ['D', 'E', 'F', 'G', 'H', 'I', 'J' ], 

}

G4 = Graph(edges)

pos = {
    'R1': (4, 3),
    'R2': (4, 5),
    'R3': (8, 2),
    'R4': (13, 4),
    'R5': (13, 6),


    'A' : (2,5),
    'B' : (2,6),
    'C': (3,2),
    'D': (5,2),
    'E': (5,5),
    'F' : (5,6),
    'G': (9,2),
    'H': (14,4),
    'I' : (14,7),
    'J' : (7,3)

}

G4.set_pos(pos)

G4.show(title="Router Coverage 4th Floor")
# Out:
# Graphics object consisting of 56 graphics primitives

# %%
edges = { 
    'R1': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H' ], 
    'R2': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I' ], 
    'R3': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R4': ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R5': ['D', 'E', 'F', 'G', 'H', 'I', 'J' ], 
    'R6': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J' ], 

}

G6 = Graph(edges)

pos = {
    'R1': (4, 4),
    'R2': (4, 7),
    'R3': (8, 3),
    'R4': (11, 4),
    'R5': (13, 6),
    'R6' : (8, 5),


    'A' : (2,5),
    'B' : (3,3),
    'C': (3,7),
    'D': (5,3),
    'E': (5,5),
    'F' : (8,1),
    'G': (10,5),
    'H': (12,5),
    'I' : (13,7),
    'J' : (14,4),

}

G6.set_pos(pos)

G6.show(title="Router Coverage 6th Floor")
# Out:
# Graphics object consisting of 70 graphics primitives

# %%
G.edges()
# Out:
# [('A', 'R2', 1), ('B', 'R2', 1), ('C', 'R1', 1), ('D', 'R1', 1), ('E', 'R3', 1), ('F', 'R3', 1)]

# %%
weighted_edges = [('A', 'R2', 16), 
                  ('B', 'R2', 57), 
                  ('C', 'R1', 14), 
                  ('D', 'R1', 40), 
                  ('E', 'R3', 30), 
                  ('F', 'R3', 16)]

G = Graph(weighted_edges)
G.show(edge_labels=True, figsize=4)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
weighted_edges = [('A', 'R2', 26), 
                  ('B', 'R3', 26), 
                  ('C', 'R2', 12), 
                  ('D', 'R2', 12), 
                  ('E', 'R4', 20), 
                  ('F', 'R2', 3),
                  ('G', 'R4', 24), 
                  ('H', 'R4', 12), 
                  ('I', 'R3', 30), 
                  ('J', 'R4', 6), 
                  ('K', 'R2', 24), 
                  ('L', 'R3', 24)]

G2 = Graph(weighted_edges)
G2.show(edge_labels=True, figsize=4)
# Out:
# Graphics object consisting of 40 graphics primitives

# %%
weighted_edges = [('A', 'R1', 12), 
                  ('B', 'R1', 10), 
                  ('C', 'R1', 10), 
                  ('D', 'R3', 22), 
                  ('E', 'R3', 24), 
                  ('F', 'R3', 24),
                  ('G', 'R6', 16), 
                  ('H', 'R6', 12), 
                  ('I', 'R6', 19), 
                  ('J', 'R6', 12) ]

G3 = Graph(weighted_edges)
G3.show(edge_labels=True, figsize=4)
# Out:
# Graphics object consisting of 34 graphics primitives

# %%
weighted_edges = [('A', 'R2', 10), 
                  ('B', 'R2', 10), 
                  ('C', 'R2', 5), 
                  ('D', 'R2', 5), 
                  ('E', 'R2', 10), 
                  ('F', 'R3', 10),
                  ('G', 'R3', 50), 
                  ('H', 'R3', 14), 
                  ('I', 'R3', 13), 
                  ('J', 'R2', 8) ]

G4 = Graph(weighted_edges)
G4.show(edge_labels=True, figsize=4)
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
weighted_edges = [('A', 'R1', 24), 
                  ('B', 'R1', 20), 
                  ('C', 'R2', 75), 
                  ('D', 'R1', 20), 
                  ('E', 'R6', 32), 
                  ('F', 'R3', 60),
                  ('G', 'R6', 24), 
                  ('H', 'R4', 32), 
                  ('I', 'R5', 75), 
                  ('J', 'R4', 16) ]

G6 = Graph(weighted_edges)
G6.show(edge_labels=True, figsize=6)
# Out:
# Graphics object consisting of 37 graphics primitives

# %%
Gm = Graph()
nodes = ['A', 'B', 'C', 'D', 'E', 'F']
routers = ['R1', 'R2', 'R3']

Gm.add_vertices(nodes + routers)
Gm.add_edges([('R1', 'A'), ('R1', 'B'), ('R1', 'D'),
              ('R2', 'C'), ('R2', 'D'), ('R2', 'F'),
              ('R3', 'E'), ('R3', 'F')])

# Removed min=True; SageMath calculates the minimum by default.
MDS = Gm.dominating_set() 
print("Minimum Dominating Set:", MDS)
# Out:
# Minimum Dominating Set: ['E', 'R1', 'R2']
